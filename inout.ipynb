# %%
### 표준 입출력

- 표준 입력 : 키보드 => input()
- 표준 출력 : 모니터 => print()

# %%
num = input("숫자 입력")

# type(num)
# 사용자에게 숫자를 입력받은후 +10 한 결과 출력
# try ~ except
if num.isdigit():
    num = int(num) + 10
    print(num)
else:
    print("숫자를 입력하세요")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 6
#       2
#       3 # type(num)
#       4 # 사용자에게 숫자를 입력받은후 +10 한 결과 출력
#       5 type(num)
# ----> 6 int(num) + 10
#
# ValueError: invalid literal for int() with base 10: 'a'
