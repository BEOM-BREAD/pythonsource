# %% [markdown]
# ### oracle 서버와 파이썬 연동
# - uv pip install oracledb

# %%
import oracledb
from dotenv import load_dotenv  # python-dotenv
import os

# %%
# .env 파일 읽어오기
load_dotenv()

# 오라클 비밀번호 가져오기
password = os.getenv("ORACLE_PASSWORD")

# %%
conn = oracledb.connect(user="python_user",password=password,dsn="localhost/xe")
cursor = conn.cursor()

cursor.execute("select * from post")

for row in cursor.fetchall():
    print(row)

conn.close()

# %%
sql = "insert into hanbit_member(member_id,name,password) values(:1, :2, :3)"
# sql = "insert into hanbit_member(member_id,name,password) values(:member_id,:name,:password)"

try:
    with oracledb.connect(
        user="python_user", password=password, dsn="localhost/xe"
    ) as conn:
        with conn.cursor() as cursor:
            cursor.execute(sql, ("hong123", "홍길동", "hong123"))
            conn.commit()
            print("저장 성공!")
except Exception as e:
    print("진짜 에러 원인:", e)
# Out:
# 저장 성공!

# %%
with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute("select * from hanbit_member")

        for row in cursor.fetchall():
            print(row)
# Out:
# ('hong123', '홍길동', 'hong123')

# %%
sql = "insert into hanbit_member(member_id,name,password) values(:member_id,:name,:password)"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute(sql,('kim123','김길동','kim123'))
        conn.commit()

# %%
sql = "insert into hanbit_member(member_id,name,password) values(:member_id,:name,:password)"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:

        data = {
            "member_id":"choi123",
            "name":"조미연",
            "password":"choi123"
        }

        cursor.execute(sql,data)
        conn.commit()

# %%
sql = "insert into category(category_id,category_name) values(:1, :2)"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute(sql,(1101,'경제/경영'))
        conn.commit()

# %%
with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute("select * from category")
        for row in cursor.fetchall():
            print(row)
# Out:
# (1101, '경제/경영')

# %%
sql = "insert into category(category_id,category_name) values(:1, :2)"

data = [
    [1102,'요리'],
    [1103,'예술'],
    [1104,'사회']
]

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.executemany(sql,data)
        conn.commit()

# %%
# 사회 => 자기계발

sql = "update category set category_name = :1 where category_id = :2"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute(sql,("자기계발",1104))
        conn.commit()

# %%
sql = "delete from category where category_id = :1"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute(sql,(1103,))
        conn.commit()

# %%
from faker import Faker

fake = Faker(locale="ko_KR")
Faker.seed(4321)

print(fake.name())
print(fake.email())
print(fake.address())
print(fake.ssn())
print(fake.phone_number())
# Out:
# 이도윤
# sunoggim@example.net
# 대구광역시 영등포구 서초중앙거리 238-52
# 670227-2018273
# 070-4938-5639

# %%
from faker.providers import internet

fake.add_provider(internet)

for i in range(10):
    print(fake.ipv4_private())
# Out:
# 172.23.126.87
# 172.19.113.154
# 10.131.127.118
# 192.168.176.9
# 10.157.113.123
# 172.27.241.185
# 192.168.56.35
# 172.19.17.156
# 10.158.11.20
# 10.137.42.109

# %%
fake.date_of_birth(minimum_age=20, maximum_age=30)
fake.date_of_birth(minimum_age=20, maximum_age=30).strftime("%Y-%m-%d")
# Out:
# '2004-08-17'

# %%
fake.date_time_between(start_date="-3y",end_date="now")
# Out:
# datetime.datetime(2026, 1, 31, 3, 26, 43)

# %%
# maru_member 50명 임의의 데이터를 이용해 삽입
# name,birth,phone,joined_at

# 50명의 데이터를 리스트에 추가

data = []

for _ in range(50):
    # name
    name = fake.name()
    birth = fake.date_of_birth(minimum_age=20, maximum_age=70).strftime("%Y-%m-%d")
    phone = fake.phone_number()
    joined_at = fake.date_time_between(start_date="-2y",end_date="now")
    data.append([name,birth,phone,joined_at])

print(data)

# insert
# Out:
# [['최성현', '1962-10-20', '043-384-1198', datetime.datetime(2026, 6, 30, 21, 44, 10)], ['박지혜', '1995-05-03', '010-1290-4643', datetime.datetime(2025, 10, 9, 21, 59, 28)], ['박준영', '1976-02-01', '053-035-5839', datetime.datetime(2024, 9, 9, 13, 27, 18)], ['이혜진', '1957-04-01', '017-103-3358', datetime.datetime(2024, 11, 13, 22, 1, 5)], ['권순옥', '2002-06-11', '044-299-1312', datetime.datetime(2024, 11, 8, 19, 46, 54)], ['안상철', '2000-06-27', '052-126-7287', datetime.datetime(2024, 10, 25, 4, 15, 47)], ['김은경', '2001-10-20', '043-812-8151', datetime.datetime(2026, 3, 9, 18, 55, 46)], ['김미경', '1974-06-20', '02-3856-5044', datetime.datetime(2024, 10, 20, 21, 19, 57)], ['김영호', '1977-01-27', '019-635-6403', datetime.datetime(2024, 9, 6, 21, 45, 49)], ['이아름', '1958-08-19', '055-626-5837', datetime.datetime(2026, 4, 14, 18, 15, 9)], ['김서영', '1991-06-22', '055-711-4329', datetime.datetime(2024, 9, 8, 7, 48, 20)], ['윤유진', '1970-11-16', '031-862-6304', datetime.datetime(2025, 3, 21, 21, 6, 21)], ['배경희', '2004-02-04', '063-524-9412', datetime.datetime(2025, 11, 24, 9, 3, 48)], ['박은영', '2002-07-14', '018-441-2107', datetime.datetime(2026, 4, 3, 11, 55, 29)], ['김영식', '2003-10-19', '062-022-4893', datetime.datetime(2024, 11, 18, 16, 0, 46)], ['양순옥', '1989-10-14', '042-597-2680', datetime.datetime(2025, 10, 5, 2, 51, 48)], ['김준혁', '1980-05-12', '017-885-2866', datetime.datetime(2024, 9, 20, 1, 5, 32)], ['진정호', '1968-11-17', '032-799-8159', datetime.datetime(2025, 4, 28, 19, 57, 9)], ['김성민', '1997-02-20', '031-419-7287', datetime.datetime(2026, 2, 6, 23, 52, 43)], ['김정호', '1986-01-17', '031-412-7115', datetime.datetime(2025, 1, 29, 18, 23, 4)], ['이정남', '1997-08-29', '042-093-8561', datetime.datetime(2025, 4, 17, 6, 52, 29)], ['김정식', '1964-09-12', '063-713-6913', datetime.datetime(2025, 2, 26, 19, 3, 25)], ['이종수', '1980-08-23', '02-9641-2299', datetime.datetime(2026, 5, 21, 16, 7, 21)], ['황혜진', '1964-06-18', '02-4171-6672', datetime.datetime(2025, 10, 10, 3, 47, 34)], ['김정희', '1986-01-04', '070-6361-9774', datetime.datetime(2025, 1, 18, 6, 27, 46)], ['정영길', '2002-10-08', '041-064-5622', datetime.datetime(2024, 9, 24, 21, 2, 56)], ['임선영', '1975-09-30', '053-325-4787', datetime.datetime(2025, 3, 5, 18, 38, 53)], ['김서연', '1959-09-09', '017-450-0681', datetime.datetime(2024, 9, 24, 20, 34, 49)], ['김미경', '1964-02-10', '019-181-4446', datetime.datetime(2025, 4, 7, 5, 7, 8)], ['김민서', '1966-09-30', '042-866-9580', datetime.datetime(2026, 1, 25, 12, 10)], ['안영호', '1976-09-18', '011-970-4109', datetime.datetime(2025, 10, 30, 11, 34)], ['박주원', '1966-04-01', '019-074-8341', datetime.datetime(2024, 11, 7, 6, 18, 44)], ['김상현', '1992-03-29', '043-693-8273', datetime.datetime(2025, 12, 19, 15, 28, 29)], ['이우진', '1990-06-23', '017-251-2991', datetime.datetime(2025, 2, 2, 12, 17, 21)], ['이건우', '1955-08-24', '054-163-7326', datetime.datetime(2026, 8, 18, 12, 33, 35)], ['장예지', '2005-11-12', '061-733-3864', datetime.datetime(2025, 2, 1, 7, 11, 2)], ['류명숙', '1991-10-18', '033-372-7015', datetime.datetime(2024, 9, 6, 7, 22, 23)], ['김영자', '1990-04-17', '055-135-9384', datetime.datetime(2025, 1, 19, 12, 52, 10)], ['전성현', '1976-07-02', '051-022-8531', datetime.datetime(2024, 9, 8, 21, 44, 51)], ['장상철', '1973-04-16', '064-718-5733', datetime.datetime(2025, 12, 25, 16, 6, 7)], ['김은영', '1985-10-20', '033-803-9197', datetime.datetime(2026, 5, 5, 0, 32, 29)], ['전채원', '1959-03-30', '041-787-9569', datetime.datetime(2025, 11, 22, 19, 28, 45)], ['김수민', '1964-04-27', '054-165-3432', datetime.datetime(2025, 7, 19, 14, 28, 11)], ['김민석', '1962-07-01', '02-1345-1828', datetime.datetime(2025, 3, 3, 8, 14, 45)], ['김종수', '1958-09-04', '064-762-1720', datetime.datetime(2026, 7, 18, 14, 25, 53)], ['김경자', '2003-12-26', '051-045-0336', datetime.datetime(2025, 6, 5, 18, 15, 8)], ['박서윤', '1972-01-14', '051-149-5272', datetime.datetime(2024, 11, 21, 1, 0, 42)], ['김상현', '1984-11-28', '054-897-2774', datetime.datetime(2025, 12, 30, 5, 34, 26)], ['박지현', '1985-04-06', '011-608-6123', datetime.datetime(202 ...

# %%
sql = "insert into maru_member(name,birth,phone,joined_at) values(:1, :2, :3, :4)"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.executemany(sql,data)
        conn.commit()
